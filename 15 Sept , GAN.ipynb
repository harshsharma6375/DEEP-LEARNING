# %% [raw]
# what is gang (genrative adversial network )
#
# 1) it is a deep learning model that can generate new data that looks like real data .
# for example ->  creating fake images of faces that looks real
#
# 2) genrative art , music , text or videos data augmentation in ml or dl .
#
# GAN has two neural network that play a game against each other .
# 1) generator -> The genrator is a neural network that creates fake data like images , text ,
# sound it doesnot get real data directly , instead it starts with random noise
# (a vector of numbers )and its goal is to make  the full the discriminator by generating data
# that looks real
#
# how does it works
# input -> it will take random noise , for processing it passes noise through layers of neural network
# then as an output it generates a synthetic data sample .
#
#
# 2) discriminator -> it is a neural network classifier it sees both real data and fake data and its goal is to correctly classify whether the input is real then a 1 or fake n is 0 .
#
# how does it works
# As an input it will take an data sample an either real from dataset or fake from generator therefore processing it passes through neural network layers then
# as an output it calculates the output based on the probabilty between 0 to 1 .
# if it is closer to 0 then it is fake and if it is closer to 1 then it is real .
#
# how does gan works
#
# step 1 -> input random noise
# generator doesnot get real data at first , it start with random noise vector
#
# step 2 -> generator produce fake data
# it is used in the noise then the generator outputs (Gz) as a fake sample
#
# step 3 -> discriminator gudges
# discriminator sees both real data (x) and fake data (Gz and it returns the output  1 if it things input is real . returns 0 when if fake , If it thinks
# the input is fake
#
# step 4 -> Adversial training
# generator want to fool the discriminator and discriminator wants to catch the
# generators lies .
#
# step 5 ->
# Loss function
# discriminator loss is ld = -(log d(x)  + log(1-d(Gz)))
# if it return 1 and for fake it will return 0 .
#
# genrator loss
# lg = -(log d(Gz))
# it wants fake to be just as real = 1
#
# step - 6 -> Training the loop
# train discriminator means make it better at catching phase
# train generator -.  Means make it better at fooling discriminator then repeat until generator produce realistic data
#
# step -7 -> Variants of gan
# DC gan -> Better for images
# cycle gan -> convert one type to another
# style gan -> it generates ultra realistic human faces .
#
# challanges of GAN
# 1) training in stability -> it is hard to  balance generator and discriminator
# 2) more collapse  -> genrator produces limited variety of output
# 3) it needs lot of data and computer power
# 4) ethical concerns -> deep fake , fake media .
